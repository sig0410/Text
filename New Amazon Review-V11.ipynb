# %%
import re
import nltk

import pandas as pd
import numpy as np

from bs4 import BeautifulSoup
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
english_stemmer=nltk.stem.SnowballStemmer('english')

from sklearn.feature_selection.univariate_selection import SelectKBest, chi2, f_classif
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import SGDClassifier, SGDRegressor
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import random
import itertools

import sys
import os
import argparse
from sklearn.pipeline import Pipeline
from scipy.sparse import csr_matrix
from sklearn.feature_extraction.text import CountVectorizer
import six
from abc import ABCMeta
from scipy import sparse
from scipy.sparse import issparse
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.utils import check_X_y, check_array
from sklearn.utils.extmath import safe_sparse_dot
from sklearn.preprocessing import normalize, binarize, LabelBinarizer
from sklearn.svm import LinearSVC

from keras.preprocessing import sequence
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Lambda
from keras.layers.embeddings import Embedding
from keras.layers.recurrent import LSTM, SimpleRNN, GRU
from keras.preprocessing.text import Tokenizer
from collections import defaultdict
from keras.layers.convolutional import Convolution1D
from keras import backend as K

import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import cm
# %matplotlib inline
plt.style.use('ggplot')

# %%
data_file = './/Amazon_Unlocked_Mobile.csv'
n = 413000  
s = 20000 
skip = sorted(random.sample(range(1,n),n-s))


df = pd.read_csv( data_file, delimiter = ",", skiprows = skip)

# %%
df
# Out:
#                                             Product Name Brand Name   Price  \
# 0      "Nokia Asha 302 Unlocked GSM Phone with 3.2MP ...      Nokia  299.00
# 1      "Nokia Asha 302 Unlocked GSM Phone with 3.2MP ...      Nokia  299.00
# 2      "Nokia Asha 302 Unlocked GSM Phone with 3.2MP ...      Nokia  299.00
# 3      "Nokia Asha 302 Unlocked GSM Phone with 3.2MP ...      Nokia  299.00
# 4      "Nokia Asha 302 Unlocked GSM Phone with 3.2MP ...      Nokia  299.00
# ...                                                  ...        ...     ...
# 20835  Samsung Convoy U640 Phone for Verizon Wireless...    Samsung   79.95
# 20836  Samsung Convoy U640 Phone for Verizon Wireless...    Samsung   79.95
# 20837  Samsung Convoy U640 Phone for Verizon Wireless...    Samsung   79.95
# 20838  Samsung Convoy U640 Phone for Verizon Wireless...    Samsung   79.95
# 20839  Samsung Convoy U640 Phone for Verizon Wireless...    Samsung   79.95
#
#        Rating                                            Reviews  Review Votes
# 0           5                                  muy buen producto           0.0
# 1           5                                        solid phone           0.0
# 2           5                                 Excellent Product.           0.0
# 3           4  pros.. it works fine, its easy to use, not too...           1.0
# 4           5                                          excelente           0.0
# ...       ...                                                ...           ...
# 20835       5                     another great deal great price           0.0
# 20836       3                                                 Ok           0.0
# 20837       5        Passes every drop test onto porcelain tile!           0.0
# 20838       3  I returned it because it did not meet my needs...           0.0
# 20839       4  Only downside is that apparently Verizon no lo...           0.0
#
# [20840 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Product Name       0
# Brand Name      3154
# Price            270
# Rating             0
# Reviews            4
# Review Votes     619
# dtype: int64

# %%
df['Reviews']
# Out:
# 0                                        muy buen producto
# 1                                              solid phone
# 2                                       Excellent Product.
# 3        pros.. it works fine, its easy to use, not too...
# 4                                                excelente
#                                ...
# 20835                       another great deal great price
# 20836                                                   Ok
# 20837          Passes every drop test onto porcelain tile!
# 20838    I returned it because it did not meet my needs...
# 20839    Only downside is that apparently Verizon no lo...
# Name: Reviews, Length: 20840, dtype: object

# %%
df = df.dropna(subset= ['Reviews'])

# %%
df
# Out:
#                                             Product Name Brand Name   Price  \
# 0      "Nokia Asha 302 Unlocked GSM Phone with 3.2MP ...      Nokia  299.00
# 1      "Nokia Asha 302 Unlocked GSM Phone with 3.2MP ...      Nokia  299.00
# 2      "Nokia Asha 302 Unlocked GSM Phone with 3.2MP ...      Nokia  299.00
# 3      "Nokia Asha 302 Unlocked GSM Phone with 3.2MP ...      Nokia  299.00
# 4      "Nokia Asha 302 Unlocked GSM Phone with 3.2MP ...      Nokia  299.00
# ...                                                  ...        ...     ...
# 20835  Samsung Convoy U640 Phone for Verizon Wireless...    Samsung   79.95
# 20836  Samsung Convoy U640 Phone for Verizon Wireless...    Samsung   79.95
# 20837  Samsung Convoy U640 Phone for Verizon Wireless...    Samsung   79.95
# 20838  Samsung Convoy U640 Phone for Verizon Wireless...    Samsung   79.95
# 20839  Samsung Convoy U640 Phone for Verizon Wireless...    Samsung   79.95
#
#        Rating                                            Reviews  Review Votes
# 0           5                                  muy buen producto           0.0
# 1           5                                        solid phone           0.0
# 2           5                                 Excellent Product.           0.0
# 3           4  pros.. it works fine, its easy to use, not too...           1.0
# 4           5                                          excelente           0.0
# ...       ...                                                ...           ...
# 20835       5                     another great deal great price           0.0
# 20836       3                                                 Ok           0.0
# 20837       5        Passes every drop test onto porcelain tile!           0.0
# 20838       3  I returned it because it did not meet my needs...           0.0
# 20839       4  Only downside is that apparently Verizon no lo...           0.0
#
# [20836 rows x 6 columns]

# %% [markdown]
# ### Rating Mapping

# %%
Review_mapping =  {0: '0',1 : '0', 2 :'0',3 : '0', 4 : '1', 5 : '1'}
Review_mapping
# Out:
# {0: '0', 1: '0', 2: '0', 3: '0', 4: '1', 5: '1'}

# %%
Rating = lambda x: Review_mapping.get(x,x)
df['Rating']=df.Rating.map(Rating)
# Out:
# /Users/Moon/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['Rating'].unique()
# Out:
# array(['1', '0'], dtype=object)

# %% [markdown]
# ### Text Analysis

# %%
df.columns
# Out:
# Index(['Product Name', 'Brand Name', 'Price', 'Rating', 'Reviews',
#        'Review Votes'],
#       dtype='object')

# %%
a = df.iloc[:,3]
print(a)
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 20835    1
# 20836    0
# 20837    1
# 20838    0
# 20839    1
# Name: Rating, Length: 20836, dtype: object

# %%
b = df.iloc[:,4]

# %%
doc = pd.concat([a,b], axis = 1)

# %%
train_docs, test_docs = train_test_split(doc, test_size = 0.3)

# %%
def review_to_wordlist(review, remove_stopwords = True):

    
    review_text = re.sub('[^a-zA-Z]'," ", review)
    #review_text에 영어만 넣기 
    
    words = review_text.lower().split()
    #소문자로 바꿔주고 그것들을 분리해준다 
    
    if remove_stopwords:
        stops = set(stopwords.words('english'))
        words = [w for w in words if not w in stops]
        #stops에 영어의 불용어를 넣어줌 
        #words는 소문자로 변환되고 띄어져있는 것이며 
        #stops에 있는 불용어를 제외하고 넣어줌 
        
    b = []
    stemmer = english_stemmer
    for word in words:
        b.append(stemmer.stem(word))
        #words에 전처리된것들의 어간들만 추출 
        
    return(b)

# %%
clean_train_reviews = []
for review in train_docs['Reviews']:
    clean_train_reviews.append( " ".join(review_to_wordlist(review)))
    
clean_test_reviews = []
for review in test_docs['Reviews']:
    clean_test_reviews.append( " ".join(review_to_wordlist(review)))

# %%
c = train_docs['Rating']
d = test_docs['Rating']

# %%
c.isnull().sum()
# Out:
# 0

# %%
len(c)
# Out:
# 14583

# %%
len(d)
# Out:
# 6251

# %%
train_docs.isnull().sum()
# Out:
# Rating     0
# Reviews    0
# dtype: int64

# %%
test_docs.isnull().sum()
# Out:
# Rating     0
# Reviews    0
# dtype: int64

# %% [markdown]
# # ================ 5/1

# %% [markdown]
# ### Tf-Idf

# %%
X_train = clean_train_reviews
X_test = clean_test_reviews 

y_train = train_docs['Rating']
y_test = test_docs['Rating']

# %%
X_train
# Out:
# ['even keep back piec attach pocket otterbox defend sever cell phone sturdi even back attach still fit shirt pocket dress shirt one much prettier other phone thus distinct understand peopl black case black cell phone look like everybodi els cell phone stupid travel black suitcas mine maroon',
#  'realli like phone everyth need time replac iphon still would use backup need like flip phone also text friend',
#  'great',
#  'excel',
#  'great phone',
#  'iphon came origin appl packag two day standard ship work verizon like ad say new condit scuff anyth thank',
#  'thisphon unlock friend use',
#  'best phone everi own fast clean sleek ton memori could ask anyth better',
#  'excelent',
#  'phone stop work week',
#  'happi',
#  'kept drop call',
#  'still get know phone well seem work ok get hot use',
#  'appear phone look put sim card function motorola',
#  'gave phone two star last long bought phone earli decemb start use januari stop work six month later batteri start overh whether charg phone alway hot recent screen start act flicker line complet blank within hour previous fall anyth say howev camera phone awesom especi price like slim design extrem disappoint last longer',
#  'receiv phone within week packag well receiv seller came phone home charger kind expect phone guid book memori card sinc use mind phone brand new excel condit perform awesom fast easi use use android system slide mechan kind hard use get keyboard figur mani time slide keyboard begin loosen littl overal great experi would recommend seller phone anyon',
#  'fantast price point high qualiti',
#  'cellphon got within time expect work pretti well far complan',
#  'great phone expect fast respons good camera think max size phone would use batteri last whole day intens usag troubl temperatur anyth relat review say first phone fingerprint sensor say work wonderful time detect correct fast lighn',
#  'phone come repow sold new say scratch beat look like honest seller soy de venezuela could return phone recommend',
#  'like',
#  'one star give zero phone japanes model fine conform japanes law japanes live japan right away notic sever featur unabl turn model phone entir unhappi purchas',
#  'disappoint product work although refund treat rude servic horribl skeptic order anyth els second incid first one handl profession topcellstuff rude even sent email tell remov comment product',
#  'think phone new sfr franc unlock phone batteri charger car charger great phone',
#  'great phone think everybodi get purchas liter hundr compani',
#  'first phone still learn use far miss android',
#  'gift',
#  'nice phone',
#  'phone expect first came without accessori u purchas separ phone seem like use phone new one even though said new like weight big sleek yes front camera flash noth realli write home bit disappoint gotten bku selfi',
#  'sold phone day left charg surpris hurt charg port turn take check coach notic phone repair bought phone new articl realli hoax',
#  'biggest scam ever seen expect amazon unlock phone actual even slot sim card sinc verizon phone pure scam buy',
#  'extrem good recept wifi howev tri find case cover difficult accident drop mine rememb order jacket protect phone find one fit dg',
#  'want smartphon cellular servic found one new amazon unbeliev low price cellular check onlin servic none came anywher near low price order phone supris two day later even though elect extra expedit ship option unbeliev sinc ship california live east coast ad phone amazon list item new receiv phone origin box readi activ notic hour use log phone even though number remov phone clear activ notic email seller issu list new usag log receiv immedi repli back within hour explain phone purchas bulk manufactur overstock could display never sold anyon offer instant refund purchas price plus postag way want return even though exchang polici would exchang anoth phone new one stock would check sure inde new also sent link site could compar cellular phone select anoth brand want elect option exchang phone like model new immedi email prepaid ship label return phone said got post offic would ship replac one without wait one return get reciev phone two day later new phone brand new immedi activ coupl month extrem happi phone particular want smartphon decid would never pay price one chosen phone particular slide full qwerti keyboard seek phone android one first activ immedi download newest android oper system found phone everyth current one market fast becam extrem interest mani app avail android market learn featur phone load app either free download everth differ ringer tone type game awesom groceri shope list alarm clock chime hour period set etc bluetooth capabl cordless home system phone compat download complet directori home system found oem lg dock charg cradl amazon cost verizon make excel light alarm clock night phone charg believ low price phone thing current one market full qwerti slideout keyboard easi use also virtual keyboard touchscreen use either horizont vertic switch automat depend hold phone also found speach text work perfect need either keyboard speak text messag phone rest handl automat new question app avail android onlin market store free work similar new iphon siri speak respond speak answer verbal question ask well carri mani function ad item calendar look address directori text email awesom love phone extrem happi find compani like seller cellular eager pleas immedi satisfact exchang phone even follow email assur receiv phone happi found compani kind custom servic unfortun',
#  'good smart phone',
#  'awesom',
#  'ok good',
#  'telephon good qualiti deliveri time factori open promis need anoth phone l buy supplyer well done thank',
#  'alright perfect phone daughter',
#  'excel',
#  'hotspot work zte',
#  'advertis packag came short time want take india gift friend worri work work without problem',
#  'phone great fast fulli function handl nice disappoint usb port burn first time charg abl upgrad kitkat att',
#  'good',
#  'wait daughter get one mine work',
#  'verizon store get phone servic work return',
#  'llegom defectuoso',
#  'bueno',
#  'great',
#  'purchas iphon got lock phone work tie target corpor read sim card model ship one offer initi return phone',
#  'bought samsung edg last februari th amazon unfortun sensor work exampl acceleromet gyroscop light sensor baromet remain compon function work proper screen microphon headphon secur intern cell phone guarante usa could return notic problem arriv argentina concern deliveri packag arriv time conclus seller sent packag time qualiti samsung edg pathet',
#  'good',
#  'phone got noot work',
#  'fake',
#  'phone great easi work comfort hand',
#  'good product use day exceed expect far updat otherwis',
#  'phone week pretti pleas due negat review read blu product expect much exceed expect fast big sturdi iphon copycat cheaper camera best get job done gotta mess alittl snap photo anyway recommend anyth upgrad lg optimus pos crap phone',
#  'everyth well describ site thks',
#  'sent back said straighttalk compat',
#  'great pros great batteri quick charg smooth transit good perform',
#  'good phone price',
#  'perfect shape work like brand new good price happi',
#  'good phone',
#  'sure last want like lot fingerprint probabl stop use soon',
#  'work great describ descript would definit buy hard scratch problem phone',
#  'expect watch touch screen work',
#  'everyth good use finley next time purchas price low whatev want thank much',
#  'super excit replac broken phone connect wifi tri coupl thing base forum luck quick return show mac address appear fair common problem',
#  'great product',
#  'wonder',
#  'nice cellphon',
#  'hard time connect stay connect',
#  'bought hasscellfre week ago use mobil g h network pretti good howev discov micorsd card read phone card work pretti good galaxi borrow test amazon excel servic allow return wish good luck next round actual love phone beyond defect',
#  'phone good price problem cover open easili batteri instal smooth',
#  'happi unlock galaxi like size excel camera good batteri life would go edg model larg expens came uk type plug charger also adapt us outlet better european us unlock great travel carri sim countri visit live',
#  'everyth great except screen bright compar full size z differ screen liter vivid still much better iphon replac would say best absurd huge smartphon',
#  'fit se perfect love',
#  'perfect exact said descript ship care load bubbl wrap label outsid',
#  'enjoy use phone love perfect everyon use trust ppl shul give tri phone',
#  'far good month everyth phone camera great use come oct rd wed record video mother make sound qualiti great music video like pandora play well loud enough leav room phone still hear play hous memori space work wonder abl download social media app plus game current run five social media four game plus shop app retail heb intern memori bought gb memori card encas screen nice size watch video youtub major plus consid old phone use complaint',
#  'bueno',
#  'biggest wast money phone broken reciev',
#  'dual sim phone love phone reason chose specif model amazon advertis duel sim phone travel lot intern need american sim one south america return stop lie amazon',
#  'excel',
#  'order phone march th promobl reciev next day phone work great look brand new could tell unfortun began noitic glitch phone auto connect wifi avail even home proxim sensor woudn work random began shut complet reason without warn last two week juli phone shut often trip south america august rd phone never turn back came back state week later went straight phone servic provid first thing rep open back remov batteri show sticker show phone defect due water liquid damag seen photo attach unfortun waaaaaaaaaaaay past return period loss attempt contact samsung told abl anyth either piss compani like promobl abl sell product total scam peopl without problem hope help updat decid accept loss contact samsung direct inquir replac warranti low behold phone receiv promobl water liquid damag sticker samsung explain month warranti automat void ask anyth could purchas phone thing could offer open repair case pay told thank instead contact amazon custom servic within two day pleas tell amazon went way help satisfactori outcom full refund amazon extrem prompt respond tell grate helpfu amazon invesig promobl hope compani like promobl stop sell unsatisfactori damag equip',
#  'funciono perfectament work perfect',
#  'bien',
#  'good iphon plus',
#  'phone smart phone indestruct excel recept amaz batteri life say field biologist live ecuador work jungl ocean sea level mountain heavili pollut citi dust temperatur rang c c one place one day meter sea level environ like cat way go work cat',
#  'phone impress price must say impress',
#  'paid new price phone one arriv use went activ sprint told prior owner left balanc owe pay order activ phone tri return phone',
#  'love use esp gym need carri cellphon pocket work good thank',
#  'servic phone terribl drop call constant suck send pictur send receiv duplic text sound suppos ring etc phone noth wrong cosmet terribl thank need phone anoth month',
#  'good',
#  'phone day everi day discov someth new even know phone light use front cam one lot space fast good clear pictur would buy one whole famili love love',
#  'realli disappoint got phone today anywher near color blue shown pictur dishearten got done set phone chines turn ship took tryst open app app keep crash realli want pretti blue phone picturesit come cheap charger nd got one mine got smash pearl white one look black blue',
#  'person recent got world smart watch learn lot short time write review hold iphon seen anyon everyth describ descript control music basic work bluetooth speaker answer phone call set alarm track step make call thing iphon get text mail social media notif android fine overal smart watch perform expect good book',
#  'phone last wife year',
#  'that nice phone',
#  'discov make appl product like use top button lock third day',
#  'phone arriv new like condit correct model verizon work perfect mobilei',
#  'look like new price okay good bf purchas',
#  'exact expect',
#  'unlock probabl new make sure read review make decis',
#  'older person construct person sport person drop kick step still work great forgot water ok',
#  'excelent producto',
#  'excel phone everyth describ seller need use blu club say check version well',
#  'good product fast ship',
#  'product good screen scratch scratch appl logo back screen issu sim card tray colour match phone color',
#  'good phone',
#  'great phone problem much go restart wise im satisfi',
#  'great',
#  '',
#  'dos job good back phone',
#  'good price better phone',
#  'qualiti case good price well made tricki put hard remov inconveni use credit card scanner love case',
#  'like phone much like motorola tundra phone fell cup espresso die',
#  'bought phone brother march brother call dad phone tell phone stop work less two month phone broken worth',
#  'name',
#  'defect unit',
#  'great phone price far happi phone',
#  'realli like style origin recommend',
#  'ok',
#  'good',
#  'excel work perfect',
#  'phone work well experienc problem bare notic light scratch',
#  'serious got case today love need new case one let dust lint drove nut want otterbox like afford pay one gonna get generic one check ebay stumbl across one free ship order check amazon found case sinc prime day ship immedi cancel ebay one order one amazon arriv went work pop love day mom get exact case friday love con fingerprint work ok',
#  'junk',
#  'nice product',
#  'good',
#  'wors phone period thing appeal size phone worthless better spend buck tablet drug caus one thing regret life',
#  'great',
#  'ran across item could beat price touchscreen bit touchi like volum button hit time without even tri overal work great item describ super fast ship high recommend seller thank',
#  'phone even month old screen turn black stop work complet appar unlock phone mess kind electron subsystem creat varieti problem never abl receiv data one either',
#  'excelent',
#  'real nice recommend',
#  'extent',
#  'pleas bit darker pictur love total unlock also happi includ free case',
#  'job well describ thank much give inform though descript product got charg ear phone',
#  'work great',
#  'realli good phone price lag sound qualiti great honest bass choppi volum go full potenti back camera good front camera terribl sound camera great phone would probabl get star',
#  'use phone two month think two month enough time abl give object review far best phone ever last phone soni xperia z soni xperia z lg optimus g htc one iphon design love way phone built light look great plastic feel like metal button back easili reachabl altough rare use like mm jack bottom phone screen screen superb qhd best get today super respons look amaz indoor outdoor anoth stori put bright control abl see direct sun light screen wow everybodi camera excel camera result amaz shoot pictur mpx mpx pictur dual tone flash realli help dark imag crisp clear also record k full hd hd fps video p video also great front face camera ok noth spectacular bad either wish lg would given user option manual control batteri batteri life good use phone hour normal day screen long batteri suffer drastic drop general good great good perform great perform run game app smooth get antutu lollipop softwar go popular opinion realli like lg android feel android vanilla limit realli enjoy vanilla android experi interfac pretti icon nice transit awesom lot choos android choic signal call phone call sound great signal alway good one big problem fact get g lte phone without get lg hidden menu option simpli get hidden menu go lte select band manual get g reboot phone phone amaz buy price go wrong oh someth els batteri remov take micro sd card gb',
#  'great phone softwar glicki',
#  'bought father realli like work well freed use line countri',
#  'phone box pretti opend would charg problem phone',
#  'pay expect dual sim phone sent singl sim phone decid go send back start use one disappoint rest fine phone work perfect even colour pictur',
#  'issu phone letter button work time time trackbal stick allow roll almost time even though phone use feel seller made buyer awar flaw',
#  'although mani app cannot get window phone actual phone great warranti happi',
#  'work well us mobil phone compani',
#  'purchas deliveri cellphon excel servic cellphon g feel like got trick cellphon g work fine',
#  'pretti cool phone',
#  'nice phone',
#  'work g lte connect g',
#  'iphon android window still favorit phone phone year old oper good new sturdi phone surviv mani drop accid even small crack quit impress nokia hope microsoft keep',
#  'batteri wont last one day come vodafon rom',
#  'phone unlock phone speaker sound blown phone volum horribl could hear phone ring time state dual sim card place volum side power button interf littl sound phone hope mad improv st z max one lot worst',
#  'first cell phone took time learn featur especi text without keyboard smaller expect look spec overal satisfi though see peopl love smart phone',
#  'lie phone unlock regist japanes cellphon compani supos gift daugther worthless piec crap',
#  'excel',
#  'use blackberri year receiv classic think like pro abil side load android app current hipchat slack okta chrome password side load touchscreen type phone number name make call within second android iphon best featur everyon fail mention mute buttton android iphon need one find self scrambl hit unmut button iphon confer call abl read notif easili lock screen loud speakerphon good batteri life abil configur notif individu email account messag servic con touch unlock appl pay screen resolut best android app sometim work correct',
#  'excel',
#  'bueno',
#  'receiv new phone knew phone new new phone state manual headphon earbud workabl audio mic flipboard logo constant imbed screen',
#  'receiv product excel happi purchas would recommend good fast effect respons seller congratul good product like purchas nice daughter like fun happi',
#  'work perfect would purchas vendor',
#  'case fit well good access function button drop coupl time case seem offer good protect complaint case dose clip holster secur time',
#  'dont buy',
#  'iv use phone month real smg f',
#  'buy htc one phone come slight misplac screen lower left leav posit second phone top horn sound distort softwar modifi phone instal sever chines applic send email htc imei said phone root softwar modifi htc could updat softwar higher version might sell new phone fault modifi softwar new buy phone seller tj globali think telephon sold remanufactur good new',
#  'perfect',
#  'shipment time take long receiv product product defect sometim work sometim supplier feedback good tri fix problem refun chang set stabl said watch realli good cell phone would give supplier posit review product good thought gsm quadband voic dial watch cell phone unlock',
#  'producto lleg en muy buena condicion el estuch es de muy buena textura los acabado de igual manera excelent protecci n para el z',
#  'like great phone',
#  'updat amazon made thing right alway buy item fulfil amazon take care buyer bewar simpli new unlock lg phone unlock lg phone logo right case find navig page go discuss amazon descript fulli truth new sure box tape tape rip user manual sticker slap technic info pre print box phone switch verizon consum cellular told seller cc might lose higher function function lost internet access mobil email live without still would like see factori fresh packag new take note use line keypad realiz line phone pay close enough attent dedic number line number phone alt function miss number line number dark blue field share key imposs see lower light keypad backlight fade quick yet found set fix also better fast dialer lack input second black display yes know would like back buy better phone threw away packag return option port number verizon cc problem generous consum cellular plan mo contract simpli offer keypad phone lineup live without featur mention go anyon go could get would give phone c grade thank todd',
#  'great phone',
#  'great phone problem took smaller sim card problem took nearest mobil dealer made smaller one chargelik phone',
#  'arriv describ',
#  'great deal look good work great',
#  'bad chosen lock',
#  'phone great screen protector uber includ amazon pleas contact',
#  'excelent',
#  'great basic phone back phone',
#  'best phone ever',
#  'excel fast safeti nice devic',
#  'excel',
#  'good phone care buy phone made china samsung honer warranti person bought offer assist would recommend bad phone nice big screen',
#  'high recommend would give star could',
#  'got wifey decent perform nice screen come accessori like case screen protector headphon like well',
#  'excel shop experi ship fast noth damag everyth describ look pictur look go farther satisfi qualiti purchas',
#  'work well glitch unlock america west indi',
#  'purchas phone use trinidad dual sim rug work well thus far disappoint camera low qualiti pic otherwis great',
#  'muy bueno',
#  'great phone love',
#  'blu hd nice smartphon good inch screen gb ram fluid aplicacion game recommend also good price',
#  'design nice although due sharp edg thick hurt ear talk phone screen qualiti awesom colour warm bright vivid batteri life poor would hard last day even light usag gps perform poor bare detect locat due lack glonass',
#  'excelent producto',
#  'arriv time scratch work happi product',
#  'featur thought',
#  'thought would',
#  'want best purchas ive made money well spent everyth say n even defin best buy',
#  'great phone im happi princess',
#  'blu dash jr k android mp unlock piec pros cheap worri lose break run smartphon app dual sim nice travellingcon month begin freez regular simpl function like web brows intern memori taken os updat good luck tri root devic make lack memori go hard find kit model camera poor qualiti obvious mp tendenc delet contact heap app run',
#  'phone came data seller factori reset phone good',
#  'mobil phone appear line still slight scratch accept found batteri charg use time satisfi',
#  'fantast thank',
#  'son love phone first day got hook start take pic ty amazon',
#  'great devic good recept good batteri life light come case screen shield one favorit featur dual sim purchas phone back regular devic travel intern impress would recommend anyon primari devic money great deal',
#  'excelent producto',
#  'fast shipper phone describ minor scratch ok n screen order',
#  'good phone need australia work awesom touch screen littl job make call use map fine take littl bit time get use touch',
#  'specif order phone receiv mobil carrier phone cool',
#  'stop work week',
#  'useless pain sent back problem though',
#  'good good sign fast get internet g depend area',
#  'blank screen glitch live otherwis wonder phone',
#  'excelent',
#  'useless work u',
#  'good phone recent use yet recomend world requir smart phone work',
#  'phone said boot error stop work turn wast money',
#  'awesom',
#  'love phone bought last year still work perfect batteri tend weaker weaker everyday use sever applic day overal still interest appl samsung believ anyway window phone great android user year switch happen easili got use coupl hour realli intuit regret switch wp phone except camera qualiti good expect most use auto mode practic set easi get believ size camera back bad think rock solid drop sever time still bright begin negat thing weight still decent definit light mayb batteri last long guess everi smart phone nowaday',
#  'excit get phone start use great text dont know one got defect phone would lose charg die everi time made phone call could complet charg phone night took charger make call would liter die within minut call dead could turn back text soon hit dial button would instant die sent back havent heard back amazon yet im actual go get refund crappi phone well see would recommend phone friend',
#  'ok',
#  'excel phone uniqu softwar architectur quit departur style format sprint pcs phone previous carrier issu various menu interfac intuit sprint phone softwar menu interfac still much learn explor far phone function go fortun cingular bless detail phone manual sprint alway neglig provid detail paperbound manual mani chart quick guid cheat sheet manual make easi hunt peck assist phone function anoth qualiti lack sprint way though previous phone blue tooth never use headset devic truli wonder hand free even dozen feet away phone make answer call love bluetooth get headset put use wont regret especi like fulli function hand go convers',
#  'realli bad phone tellm speek featur lauch reason search lauch reason even earn one star',
#  'like lot devic thing came low cheap qualiti ac adaptert look like one buy groceri shop half dollar accesori came within seal box headphon sim remov usb adapt charger devic etc',
#  'love',
#  'good receiv broken entranc shipper screen recommend',
#  'excel phone overal qualiti control issu screen even great perform dual sim awesom fingerprint reader work well',
#  'bought lumia stolen sinc came good camera still one best mega pixel one th lumia purchas issu problem replac warranti bought use april last month bad huge minus motherboard simpli decid give one gave mom year old girlfriend one year work great unclutt good camera good like phone simpl comput combin still best camera metro os would chang stick price replac strike pictur even key thing keep microsoft bought nokia destroy mani big compani wonder nokia could made surviv competit period uniqu ident need year recip increment improv',
#  'phone good shape work order bit help mobil remov previous user inform well howev month complet unreli sometim work sometim batteri life atroci total wast money',
#  'phone work well need backup phone unlock perfect fit',
#  'theori love phone function set eas use love stylus note take particular favorit featur nerd like jot note without look keyboard open app super handi dark room listen nerd said love talk stuff howev version awesom realiz purchas intern version use us fault admit us adapt european plug come phone handi travel intern next littl handi need worri convert guess except fact never servic anywher phone manag two measli bar servic even alway actual send call dig specif deeper today purchas sever month ago realiz even though say servic mobil actual fulli support mobil guess issu kid differ phone issu servic locat even notic could connect wifi call option version even better phone sens call super import decid enough connect ring sure sort voodoo frustrat hell client call straight voicemail kid puke gut broken arm school rough recess right straight voicemail text super cute guy hope see come enough delay order text mess clear clever intent make look like dork fair take much voodoo somehow manag get everi sale call though yup voodoo know fix mayb univers tell move belgium model perform belgium idea got better mobil buy phone',
#  'work well problem far',
#  'glad order everyth product price deliveri time well strong recommend',
#  'need replac old flip phone fit bill number transfer sim card run sound qualiti good work great instruct one like problem',
#  'good',
#  'batteri work seller custom servic prompt replac devic good good seller',
#  'alway otter box best oop drop phone',
#  'overal good batteri die fast scroll click everyth',
#  'incred disappoint waist money phone g describ att well nut even activ unabl return money gave child gift extrem excit made disappoint even harder swallow realiz complet useless',
#  'use htc tilt sever year need replac current one becam damag year use abus carri multipl phone includ current model iphon blackberri torch window htc tilt main workhors allow access multipl hospit network use differ communic paramet without much difficulti chang medic industri slowli adapt continu use tilt',
#  'great',
#  'incred disappoint waist money phone g describ att well nut even activ unabl return money gave child gift extrem excit made disappoint even harder swallow realiz complet useless',
#  'junk even two month turn money garbag',
#  'spen work',
#  'muy bueno',
#  'wow good stuff love phone work perfect thank amazon',
#  'esto puedo opinar ya q fue un error',
#  'nice smartphon fast full day batteri amaz pictur lag bit sometim',
#  'work great issu speak arriv quick describ',
#  'color pictur',
#  'excel product qualiti',
#  'incred phone also first window phone love worth everi penni spent',
#  'samsung sch galaxi gb android smartphon verizon gsm black certifi refurbish disappoint receiv breed everyth make receiv phone call',
#  'price great',
#  'said phone normal wear lie phone complet scratch someth sharp screen like razor blade someth paint peel hard see pictur screen worth money disappoint mayb worth five dollar complet lie rip',
#  'love',
#  'receiv product work okay seventh day product stop charg outlet could charg friend pc given inform would tell receiv product make sure charg via outlet pc make sure noth charg port charger plug batteri damag also see long would take charg took phone charg hour get full charg would order phone recommend phone friend buy',
#  'turn day got wet work suppos water tight abl handl littl water piec crap got littl wet work wish save pack receipt could send back',
#  'bought phone mom sinc need smart phone like style phone light weight easi use con volum button side phone adjust volum',
#  'love although like volum music listen go louder happi huge fan asus version android relat cyanogen os googl nexus android os bad gb ram make huge differ speed like gb intern memori gb micro card slot mention abil read anoth gb usb port batteri life could bit better much better iphon get day normal usag',
#  'phone nice design feel solid batteri strong speaker voic qualiti adequ big problem phone kb ten kilobyt memori avail take photo set wallpap rington unless instal memori card price great phone elder work quit well fm radio pick station without headset recept weak other note',
#  'bought item new send refurbish phone import tell truth costum condit phone order avoid negat comment howev need say telephon work realli well insid outsid countri',
#  'g phone',
#  'workdefect',
#  'satisfi',
#  'great phone smooth android experi nice size good feel hand realli enjoy phone month devic began problem charg due actual charg port insid slide back work blu custom servic easi work exchang receiv new energi x plus like first one great phone month began charg problem current',
#  '',
#  'nope awesom phone product got amazon satisfactori phone put heat frequent hang freauentli plan lodg complaint get good one atleast refund',
#  'advertis',
#  'take nice pic',
#  'thank ship fast cellphon new mucha gracia funciono en mi pa per',
#  'love phone',
#  'work phone charm continuum mirror cast good latenc howev phone run fluent w screen butteri batteri life downsid notic yet',
#  'good got year ago date',
#  'amaz',
#  'get recept area great call',
#  'crappi work',
#  'got time far work great come headphon sim extract pin regular wire charger come charg base need bought separ',
#  'granddaught disappoint like pictur',
#  'nice',
#  'bueno',
#  'expect someth way cooler work kinda cheesi compar samsung newest watch sent back',
#  'great band day friend fitbit charg believ mine work well use dayday band app suggest iphon plus work great sync automat bluetooth keep accur track test time friend fitbit charg also alert call mms notif definit plus carri phone time would like order color',
#  'good buena',
#  'use st gen moto g nd gen moto x expect similar build qualiti know went hill lenovo acquir motorola googl happen get two phone bad batch first phone start exhibit ghost touch day use phone contact motorola custom support ask firmwar softwar updat fix issu told agent behavior typic return replac find fault amazon replac polici new unit sent next day new phone start thing quick googl search brought result other issu fix avail standard answer lenovo support forum take phone local repair center phone work great app respons fingerprint reader speedi display sharp realli like use howev phone start act would switch screen open app type even call sister explain wonki happen one phone justifi tri twice row need go back refund',
#  'good',
#  'custom servic good watch good price need download app blu tooth concern blu tooth app',
#  'situat tha upload new softwar chines yes chines',
#  'order phone said would work w straight talk dosent love phone',
#  'good',
#  'excel',
#  'love phone samsung boss',
#  'love phone week problem differ brand phone gave bought one talk seller got return polici decid tri work great love size happi',
#  'producto bueno',
#  'wi fi hotshot work say contact sinc unlock activ account otherwis great phone smooth lightweight slim',
#  'great phone money everyth want',
#  'everyth expect',
#  'camera qualiti certain superb',
#  'far good samsung mini screen size galaxi far optionsdon realli care thumb print scanner id hard time recogn thumb even though idid suppos biggi prefer use pattern anyway',
#  'thank',
#  'volum button work dissapoint',
#  'disappoint phone thank work mobil account arriv earli love featur good buy',
#  'first hate phone model love one three year start get glitchi like model much want anoth purchas one product descript tell phone refurbish within two month purchas phone problem old phone find model somewher els get like phone buy',
#  'own mobil wifi brazil live sinc internet recept quit bad mobil one let roam around find best spot huawei product excel',
#  'appl iphon meet expect keep go iphon alway warm thought new iphon like phone given mani problem right watch ok bt iphon good condit charger recharg iphon',
#  'receiv today simpl seem good enough backup phone post coupl year see withstood power time updat one week purchas phone pretti bad sound qualiti peopl hear bad hear bad also backup phone cost buck call qualiti import aspect backup phone look elsewher batteri life insan though main want dock star',
#  'product good qualiti open box friend one actual use comment well work',
#  'great phone home unlock phone',
#  'nice nice',
#  'suck period',
#  'great phone seller sent time downsid plug uk socket great camera fast love waterproof',
#  'item meet intend purpos',
#  'good phone good price go wrong htc one samsung galaxi next gen phone even better',
#  'upgrad phone galaxi note iii load better faster better screen much better camera love camera display clear colour simpli joy hold behold drawback hold care press wrap around screen confus want worth bet',
#  'exact paid phone great condit packag safe great buy complet recommend',
#  'bought phone daughter guess use modern smartphon found one cumbersom serv purpos thing like lanyard hole small cant get anyth',
#  'phone work good speaker good',
#  'data connect work well warranti provid replay email call look email funni',
#  'cellphon packag seal cellphon scratch screen well back side overal find lenovo upto mark per price hardwar configurationon caution chinees cellphon might expect chinees languag eg hard reset phone book etc',
#  'great phone good relat price equip excel camera',
#  'great job',
#  'good price',
#  'samsung convoy much sturdier earlier phone arriv quit quick verizon personnel set w problem extra charg',
#  'aw screen doesnt work click slide anyth cannot open unlock',
#  'bought phone order use mobil network howev sim size phone nano micro sim card cut micro sim card abl make work perfect also order get data connect mobil need insert network manual sever video youtub show step step phone work perfect packag perfect well',
#  'receiv wrong case size wrong design',
#  'thank',
#  'good',
#  'bought four son switch phone carrier never got use seem like great phone careless teenag',
#  'high qualiti product person advertis surpris overal look book imag clear step step well done',
#  'great phone',
#  'nice',
#  'thing basic get work gps locat slow sketchi best must set wego app pre program phone number call text phone receiv text approv number list pre instal respons leav pretti limit like send text messag notifi messag read notif panic alarm pull take minut opinion way long kid oper touchscreen smartphon better push button front side control scroll back button littl tricki figur abl dial nine one one easili entic featur find want remov phone accident dial time push ok button fast sprint wego plan month includ minut text cours data think pretti good deal fyi pay attent review amazon custom know somebodi list name amazon hide screen name seem everi time see multipl review complet wrong advertis product like written seller',
#  'excelent producto',
#  'good',
#  'awesom phone tri buy anoth one sorri stock',
#  'month stilll amaz witv phone excel concern poor batteri life deplet un hour surf quick video sms short call',
#  'item describ fast ship excel custom servic high recommend',
#  'phone arriv perfect condit expect howev phone well built sever repair made phone without inflict actual damag sometim screen work home button fall vibrat sometim sudden work within first month phone use iphon sever year last one make switch soon possibl',
#  'great product',
#  'great phone great price',
#  'phone horribl handl due edg month use screen went black cannot use phone anymor see still noth shown screen consid buy phone wast money',
#  'clean phone like thank',
#  'great',
#  'amaz devic',
#  'work snappi use rain come fill bloat ware speaker work well reason star rate poor qualiti close pictur taken camera sinc use previous phone camera copi document find workaround come discov oper error star',
#  'love new soni z iphon user sinc first one came skeptic switch android os soni done great job keep thing relat simpli ui wise compar friend nexus run stock android soni stray far away stock android function everyth most stock system ad touch well integr come bloatwar non invas user experi take intern memori easili compens good size micro sd card everyth multi task easi run smooth user interfac clean look aesthet pleas well organ look clutter bunch thing clean look interfac someth notic differ samsung touchwiz someth notic chanc play around friend galaxi decid new smartphon purchas touchwiz quit clutter theme aesthet pleas eyesor despit fact love ole technolog samsung one use display tech theme skin nice look soni still much better grasp design aesthet korean reviv anoth plus great imag underwat camera absolut fantast camera could hard use auto mode may best though bad could better manual mode camera outshin iphon sure speak phone camera trust soni put best sensor phone make almost sensor iphon smartphon compani soni make fantast camera dslrs snap shoot also creat imag sensor medic use camera use profession film industri technolog pack small littl smartphon camera work wonder heat issu associ qualcomm snapdragon chipset regard heat issu bad make seem realli show problem use ar mode k camera app unfortun k great ar mode quit fun use overal though heat like phone come multitask long phone call run heavi app game intens graphic waze bothersom rememb thing would caus iphon get pretti hot realli issu guess get bit hotter phone realli blame soni least own fact get hot tri address issu qualcomm maker chipset even problem affect soni htc lg coupl flagship model shame qualcomm ignor custom overh deter buy phone awar samsung also suffer heat issu look samsung heat googl issu get overlook samsung sell mani phone googl show bad stuff first like yelp show recent bad review restaur unless refin search htc also heat problem associ soni heat issu use camera app k mode ar mode everyth els work great love give soni shot look tri android want buy new android usual htc samsung lg',
#  'love',
#  'got phone use vacat portug bought pay u go sim card work flawless abl call state text etc buy nice got fast brand new',
#  'bought present dad mani peopl htc facebook first even surpris otterbox case dad phone year know quit time longer case made dad phone look brand new joke around dad bought new phone present believ case appear durabl give rug look enjoy person simpl come phone case clear case galaxi purchas otterbox someon need extra protect imo best protect come phone case prefer rug look go brand long mind make phone appear bulki',
#  'work bad phone',
#  'great buy',
#  'muy bueno',
#  'ok',
#  'anti pay much phone type person like buy flagship phone high price mayb use work mobil phone compani get free like tech use type mobil os android still favorit like told use phone want decent price phone hardwar need run app need look nice well honor definit disappoint got gb ram everyth run smooth drive space import sinc allow microsd card got gb also look pretti nice metal back look cheap got sapphir blue differ love got dual camera back still figur better use pictur pretti good slim nice size big small price nice phone sure handl drop yet got screen protector also back cover put use overal game video play phone run smooth import love',
#  'thank contact seem softwar challeng screen went blank tri restart avail day use sim card similar phone start far problem',
#  'bought use verizon work say use differ sim unhappi told unlock could use servic',
#  'good',
#  'switch',
#  'recommend seller product led quick unev',
#  'nice littl phone send back stop receiv call',
#  'phone pristin condit work feel amaz im switch iphon phone heaven',
#  'batteri last hour goe minut',
#  'phone charg',
#  'great camera screen somewhat fragil first smartphon ever broken screen within first month',
#  'got iphon gb spacegray day back well work smooth without glitch honest bit hesit first sinc refurbish phone excel mint condit price realli afford comparison differ websit mobil prepaid sim card work perfect ship super fast well sinc need phone urgent drop previous phone water satisfi custom',
#  'phone work flawless howev batteri came phone fake believ nfc support even though enabl set also batteri life poor even last full day overnight charg seller agre replac chang rate',
#  'excel',
#  'good phone',
#  'phone good batteri last long besid good',
#  'excel',
#  'excelent recomendado',
#  'repeat buyer phone great camera phone best camera mp low light imag awesom phone perform also good',
#  'thank good price',
#  'money phone realli great everyth high end phone got phone son first phone',
#  'got littl brother softwar realli nice fast hardwar littl weak screen brother drop screen got bunch black pixel take care',
#  'excel',
#  'screen vertic line sinc day exact day purchas today usb connector phone gave connect devic charg batteri cord plug frustrat warranti ran day ago phone receiv bad treatment though pass water test briefli submerg bucket water second first week realli worth dollar opinion also prospect buyer note worthi deep set posit micro usb femal connector accommod waterproof featur insert plug extra long possibl buy micro usb cord use work without modif male micro usb portion cord',
#  'power machin low price beauti screen best experi watch video ship fast phone estim deliveri day android',
#  'work great seller great support',
#  'receiv replac revel pro x phone spend day play would say phone great replac origin purchas phone dual sim card function although mani perk phone call clariti fm radio speed would say impress phone compar galaxi phone market time tell softwar actual devic withstand normal use overal satisfi replac posh mobil sent pleas feel free ask question felt review help anyway pleas click yes',
#  'clear mid rang android devic pick blu studio hd lte becasu want see could get hang thing android side switch least cross appl side thing challeng one week enjoy experi continu use phone unless find reason first phone cost less usabl reason warn updat need box set probabl need tweek user like hey that one get android phone right freedom customis said ignor troll bash one liner actual pretti decent phone lot go pluse durabl glass screen durabl respons correct origin review indic gorilla glass sorri model come screen protector alreadi instal spare box speed adequ standard use game use lot app simultan may want premium phone attract basic candybar smart phone easi hold easi use slipperi prone drop come silicon rubber case good enough lte g fast hd screen notic differnc non hd model cheap averag good build qualiti despit plastic back feel solid get set ui kitkat come pluse minus suchscreen color good bright call qualiti good hold signal well urban area need work gps system bit sketchi googl map waze fix hold full reset use gps fix app reload gps info accuraci set set high question still mind whether particular phone accept replac primari phone gps read googlo map waze slower iphon despit day tweek fix see batteri life also mediocr standard data use requir daili charg safe overal great deal less door light attract littl time invest front set blu studio hd lte solid unit far work advertis hope help updat june month usag throw around phone hold quit well screen remain intact nice clear origin screen protector place found suitabl phone case silicon rubber one came hope billfold type would allow stand said hold quit well gps suck plain simpl may android thing lose lock regular virtual unus gps nav unit except best weather scenario fact complain live california undergo drought tell poor think part function said though folk wont matter phone function well crash yet high recommend upload googlenow replac launcher came phone',
#  'thank',
#  'two differ pair batteri sent none fit item also return escap button work never purchas anyth pink monkey',
#  'great protect',
#  'phone truli rug freez much even realli anyth',
#  'excel cellphon',
#  'happi phone though even use function',
#  'good',
#  'husband love new phoneeasi hear ring easi open overal perfect use slip hand',
#  'es buen tel fono tenido problema con el es r pido lo recomiendo solo un pequ detall que la bater dura poco tiempo',
#  'work great',
#  'nice phone wrong carrier send back problem',
#  'item factori unlock work south america pay extra unlock work ok',
#  'lovee classic someth nice go back blackberri everyth well organis sure miss app app world amazon app store googl play sideload good high recommend',
#  'pass everi drop test onto porcelain tile',
#  'nice design easi use step iphon use one diffrent purpos',
#  'amaz came exact birthday thank',
#  'good stuff',
#  'let first start apolog e seller phone amaz want think attempt extort sim card exchang glow review apolog misunderstand regard compani reput integr anyon purchas devic sim card includ due feder privaci law howev purchas devic need sim card visit corpor verizon wireless store sim card given regist free charg phone awesom price equal impress grievanc incompet u postal deliveri confirm system dimwit u postal employe deliv parcel flag deliv pm caus massiv confus anguish actual deliveri time occur pm even definit busi compani go forward',
#  'durabl littl phone haptic feedback button littl weak sideth display good one thing onscreen button close home button pushfingerprint scanner goodth case cheap get dirti fast',
#  'phone purchas trip europ need data capabl phone market global phone tri us work perfect sim card howev europ differ stori good voic good sms data except anem intermitt g orang servic franc vodafon spend hour orang shop tech final discov data frequenc phone oper avail america europ solid phone use america global phone mean keep phone backup us need differ one next trip europ',
#  'phone look perfect shape howev week use phone call seem lot static would automat disconnect unabl hear heard disappoint process get refund exchang offer',
#  'base commend web sound like one would work mobil lte well give shot far tri enabl differ radio softwar got hspa hspa faster galaxi nexus good news phone work tzone plan mobil stop day time tell speaker loud clear like htc one like screen size stylish would get c lte instead',
#  'id mail password',
#  'week start get black screen would difficult get come pack even press combin hard key two soft key day later lock screen would come pale green read elsewher black screen seem common separ issu samsung like load phone lot crapwar cannot remov turn app generat warn possibl problem',
#  'exceent',
#  'ok',
#  'phone work good featur cousin look cost afford batteri dead less yr phone dead less yrs cannot recommend phone star look initi work natur perform',
#  'brought daughter great problem phone think layout phone good pictur great phone receiv send messag like would ring call sure network phone phone none issu',
#  'look even greater pictur also feel easier smartphon class',
# ...
#  'phone work would turn terribl experi',
#  'love phone bought anoth backup want ever loos product bought one elder father abl see use',
#  'perfect',
#  'phone worthless seem like everyth phone stop work buyer bewar buy phone',
#  'describ got sooner expect happi',
#  'beauti phone great perform phone handl could throw far game freak phone ought abl handl game like asphalt full graphic set problem far problem game load fast smooth slow drop frame ever often screen beauti watch answer question know may led notif light minor although would ad flare consid size bezel top gb avail storag easili increas via micro sd use gb samsung micro sdhc card problem recognit devic select option use micro sd default storag notic certain app help instal way intern memori phone result littl intern memori use littl atrix gb rate intern memori gb actual memori could option instal app sd without root phone even problemat gig enough still sever larg game time like asphalt modern combat like far abl instal asphalt card whole decid download other well expect storag problem unless tri download instal larg app effici ram bloatwar fourteen app open time includ asphalt netflix facebook almost half ram still avail check make wonder would happen gave gig ram know peopl suggest gig far enough suspect core make ram usag much effici two sim one mini regular size sim micro size easi instal sim instal get option make one sim default call text data separ sim use call desir sim could use aspect sim micro sim addit know batteri seem drain littl faster one sim instal realli investig sure someth keep mind android dish seem come th month skeptic upgrad sinc announc made blu facebook page even websit time decid tri offici patient upgrad process interrupt way far phone feel much fluid noth extra special notic yet cours play around batteri life accept best think thing like least phone standbi batteri last mind use let say instant messag via whatsapp facebook littl game music get around hour seen far sinc core processor mediatek expect stellar batteri life screen time impress much much limit within hour instead within hour could done alot better batteri hope updat make better use batteri mayb could creat better mah perhap larger mah mah batteri fit phone still consid price better good mani devic price speaker clear clean loud enough like phone come beauti music player offer sever sound effect like plate reverb larg room etc along differ play mode like classic danc hip hop pop etc said feel desir get anoth player googl play store redownload fusion music player allow user cut song point make desir rington also allow onlin content use featur respect speaker though think probabl could place front consid much bezel present capacit button could place smaller one work well back nonetheless lean onto someth solid play video sound resound beauti wi fi antenna seem pretti strong travel around pick wi fi signal home pass bar connect home wi fi quick call qualiti good made short call far individu hear clear sound clear also background nois drop call far good set allow suppress background nois call camera function well take clear pictur flash back bright enough take good pictur night interfac minimalist clean one issu whenev video icon touch camera automat start record video know chang set yet keep look tri bluetooth yet say stabl use yet headphon special expect experi best sound good enough come mic someth notic use screen type sometim press area time wait second two get letter went audio set disabl vibrat feedback help littl still happen though less frequent therefor one two thing softwar problem fix updat ii particular phone minor fault still take away usabl phone sinc happen ever often last second ran antutu benchmark sever time highest score ever got ram usag great show better phone comparison vs galaxi may take time get use posit capacit button background light goe second without interact sometim search bit well lit area problem see without background light think allow chang long light though hope includ updat phone work need pay us dollar brand phone like samsung htc blu come much offer accept price compar moto g price get alot valu money updat dec use phone month minor issu final posit realli tri bluetooth far disappoint tri sever bluetooth ...
#  'phone work perfect still sever month',
#  'phone constant cut self',
#  'super easi use interfac realli long batteri life went two half week need charg far complaint easi open phone past peopl end often hard time hear talk besid radio work well super simpl type text messag app auto complet old fashion get l',
#  'got mom christma far love think get one',
#  'good whenev use keyboard type phone see alphabet type see screen littl good help avail type',
#  'daughter seem happi invest money earn',
#  'shipment time take long receiv product product defect sometim work sometim supplier feedback good tri fix problem refun chang set stabl said watch realli good cell phone would give supplier posit review product good thought gsm quadband voic dial watch cell phone unlock',
#  'excit phone final gonna get soon',
#  'work two week two week dead mp work blue tooth realli recomend wast money',
#  'phone also work proper ear piec faulti way hear call put phone speaker mode refund howev prompt without issu',
#  'bought phone deliveri time start use phone gave troubl network phone nice give troubl make frustrat use',
#  'nana love',
#  'exel',
#  'new champion mate fantast phone blaze fast samsung loyalist lol huawei new top dog seller excel deliveri',
#  'pleas nice phone money spent pretti simpl navig set issu window phone get app could iphon differ android love set limit internet perfect starter phone child',
#  'deliv time us version intern version phone galaxi back real galaxi afraid chines knock much third parti seller hard know reliabl took chang al good far',
#  'use g want surf web im',
#  'great watch movi pictur portabl',
#  'fast ship first last iphon alway android window phone power user window phone perform phone expens product bad wifi phone left right next wifi sourc disconect issu poor preform bad bad batteri life leav phone airplan mode listen slacker radio via wifi said batteri last close hour one speaker work first iphon know iphon problem seller problem product come cheap charger realli need buy product buy extra charger charger last week even fact phone get littl use review base fact use listen slacker radio via wifi experi imagin fast batteri die turn airplan mode rate scale give product bad bad bad',
#  'like far anymor defect hang drop call loss internet thought problem provid chang provid ever sinc still',
#  'post hone awesom grant jump pretti old lg g yet still fantast piec equip love googl love phone',
#  'work great',
#  'yes phone book made right though phone turn batteri go dead took batteri would clear turn phone call receiv call text samsung convoy hrs talk suppos new pi',
#  'final get phone work abl use bit month would receiv complet text stop ring make nois alert msg call biggest piec junk purchas site mention marit prob caus bc inabl communic effici bc phone bad buy even toy juuuuuuuuunk',
#  'excel product fast ship',
#  'never use phone case otter box never ever damag done phone otter box pink littl lighter pictur still cute',
#  'good product like much',
#  'far best midrang android phone fluid use almost hang processor ram con intern memori comprehens fact wto intern space instal app could end crash reboot memori root understand improv issu still work beginn recommend buy anoth android one day better hardwar',
#  'shame solid purchas ship compani place order receiv dirti use phone ship flimsi soft envelop bit bubbl wrap certain ship small box appl box previous open corner smash phone cover greasi fingerprint attach except cheap earbud miss info oper instruct identif lock wait three day obtain approv solid crap purchas return wait refund ship compani associ amazon better wrap care deliv item comparison fragil new appl iphon cost sever hundr dollar never purchas anyth solid purchas avoid big disappoint experienc consid select anoth shipper',
#  'devic came without origin packag pack sent unopen sticker one side nokia lumia imei code pack nokia lumia ppack would find googl search mean box wasnt nokia sure manual connect cabl pack',
#  'receiv phone coupl day ago say lte phone spent hour tri make lte work addit spent hour research websit lye fix phone old phone lte work fine att problem addit wfi connect phone kept drop time enter password get reconnect time decid one go back request return even famili sever window phone work fine think phone box say destin saudi arabia u mayb would work better',
#  'amazon hope sale second hand mobil phone establish standard limit certain unscrupul businessmen shoddi second hand mobil phone hope bad busi strict enforc amazon proprietari standard use phone',
#  'exact list great custom servic',
#  'excel blackberri friend univers plan chang blackberri one thing like bring leather case neither memori card besid happi',
#  'went iphon g htc evo g sinc bring evo new carrier purchas unlock phone search month want pay much money new phone stumbl upon blu dash thought great deal littl first week complaint everi review complain sticker come screen big deal unless extrem fat finger peel sticker second week start get glitchi sd card would unmount sudden app get slower text huge pain seem like would text random word realli tri like seem hardwar good enough support android softwar would take realli long load would restart phone everi day suggest spend buy unlock iphon g cheapo like cough anoth hundr buck make invest better qualiti phone get pay nokia lumia way',
#  'got brand new moto x quick wait till favorit app open',
#  'uniqu stylish love good price',
#  'first experi smart phone technolog want someth larger phone eye issu fit bill perfect larg enough see dial well text size adjust key pad larg sever question use e mail compani quick clear answer googl base real problem hook carrier one around includ store onlin ever heard phablet figur abl hook without problem run g abl play onlin game make call without problem downsid see batteri could better good product',
#  'speak spanish probabl would great phone return love amazon',
#  'work great need skill set',
#  'phone lock expect unlock phone htc freestyl f pd need unlock return',
#  'connect network call support said defect dare tri anoth one even though connect wireless fast luckili amazon alway took back disappoint',
#  'send phone fast get check phone key menu poor condit mean key work bought new phone noth shabbi cover warranti communic global mobil store bought communic',
#  'expect someth faster decid return done research made purchas',
#  'love',
#  'bought phone replac nokia anoth great nokia phone complaint great connect great photo anoth satisfactori product nokia',
#  'buyer bewar phone scam send receiv call text put perfect good sim card work good unlock phone',
#  'excel',
#  'far good month issu hard time locat good iphon price rang great shape',
#  'case natur evolut se phone fullfil expect',
#  'excel product great qualiti nice price inde unlock use telephon compani verifi g band work countri plus lenovo technolog',
#  'excel product good servic',
#  'phone everyth want phone could download sip phone accept call voip also use magic jack app make call cost magic jack app crystal clear talk phone write say type text email talk search locat anyth want googl great phone imagin samsung galaxi phone',
#  'call get drop everi word cut batteri charg unit refurbish look like new hope complet test appar send back',
#  'suppos unlock phone coulden unlock even seller instruct',
#  'broke verizon dna replac suppos phone phone consider slower recept terribl default sound cannot turn hear notif sound take full minut email avail andther notif littl bar top disappoint phone',
#  'work like great condit',
#  'good phone price howev volum serious setback phone',
#  'good',
#  'phone state metro pcs came app unlock phone use carrier simpl app unlock less second sim card month metro pcs servic came mine',
#  'bueno',
#  'excel condit describ arriv time',
#  'love everyth phone purchas replac samsung drop size display screen j still adjust larger size phone phone receiv exact describ dual sim slot memori card slot purchas gold color exact shown amazon phone unlock work perfect bahama issu set receiv brand new phone seal box day order prime seller also sent email offer support may need would definit recommend phone',
#  'buy recommand meet expect',
#  'good good audio output input hear phone convers well',
#  'got exhibit ii secondari phone realli good phone pros screen size shabbi sub phone multi touch screen detail crisp decent spec singl core ghz processor gig intern memori front face camera video conferenc sold phone abil skype video gtalk realli nice good batteri life phone easili take day averag use get hour singl charg con deal lot mobil bloatwar cours alway root phone delet bloatwar mobil may give hard time unlock phone purchas sinc travel oversea lot need phone unlock read individu eventu gotten mobil unlock exhibit ii sever call lucki go elsewher unlock mine buy phone unlock use oversea check sure network compat exhibit ii g network gsm g network hsdpa sever countri africa europ use mean phone get g network found travel oversea overal regret purchas',
#  'actual love droid slide keyboard particular refurbish one got seller januari final put action activ day tinni vibrat metal nois echo everi word phone call obvious disappoint slight slow freez briefli time like one though bad otherwis work okay good thing make mani phone call help annoy need use phone talk wish taken time test phone call aspect deem fit sell peopl obvious case activ back got abl return sinc wait realli need switch phone howev seller motorola test sell make sure work proper around lousi job make sure par give star reason new droid probabl work fine would buy refurbish phone unless need one back',
#  'work perfect initi phone went bank start lost info',
#  'excel',
#  'got phone may first coupl month great sinc major problem charg phone use microphon random softwar glitch effect render phone useless price great deal worth risk want guarante phone perform recommend purchas one',
#  'phone receiv mess glitch count',
#  'love',
#  'fit like glove happi son autism durabl',
#  'nice phone happi fast ship accessori includ good deal',
#  'phone arriv ok function fine one month problem start phone constant reboot time get stuck hard reset possibl need wait batteri die next thing phone die altogeth warranti shipper thecoo stuck brick know fix expect poor perform suppos top line phone mayb intern version fishi strong advis buy phone',
#  'one star enough said',
#  'asian gold version work great cricket servic faster cheaper store',
#  'work',
#  'spent hour verizon store never abl activ phone bought new never work huge wast money',
#  'bad realli good test sim card mobil also att work perfect phone good recommend peopl get good work mobil att',
#  'excel',
#  'took min start plus need piec open sim card slot feel look amaz',
#  'everyth fine',
#  'would gave five star month later drop screen complet black unrespons howev love phone work perfect spec awesom',
#  'day review zte axom pro complet blown away capabl phone main got k uhd video capabl tri video dark noisi bar band condit well daylight love phone also first phone impress play music speaker rock yet use earphon came phone easi use initi set pretti intuit phone current use net issu wifi rang realli great',
#  'perfect work good wife samsung galaxi',
#  'phone came quick phone work perfect',
#  'os worst prefer window phone instead ofcorc phone android best among even good window phone buy',
#  'happi phone amazon servic alway',
#  'phone work great',
#  'nice design qualiti assembl gap bodi great hd screen wide bright set max bright phone usabl even direct sunlight pretti power hardwar enough game whatev overal stabl operat',
#  'phone meet expect scare first excel condit worth money',
#  ...]

# %%
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.pipeline import Pipeline
from nltk.corpus import words

# %%
vectorizer = CountVectorizer(analyzer = 'word', 
                             lowercase = True,
                             tokenizer = None,
                             preprocessor = None,
                             stop_words = 'english',
                             min_df = 2, # 토큰이 나타날 최소 문서 개수로 오타나 자주 나오지 않는 특수한 전문용어 제거에 좋다. 
                             ngram_range=(1, 3),
                             vocabulary = set(words.words()), # nltk의 words를 사용하거나 문서 자체의 사전을 만들거나 선택한다. 
                             max_features = 20000
                            )

# %%
pipeline = Pipeline([
    ('vect', vectorizer),
    ('tfidf', TfidfTransformer(smooth_idf = False))
])

# %%
X_train_tf_idf_vector = pipeline.fit_transform(X_train)
# Out:
# /Users/Moon/opt/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py:1278: RuntimeWarning: divide by zero encountered in true_divide
#   idf = np.log(n_samples / df) + 1

# %%
X_test_tf_idf_vector = pipeline.fit_transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
forest = RandomForestClassifier(
    n_estimators = 100, n_jobs = -1, random_state=2018)
forest
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=2018, verbose=0,
#                        warm_start=False)

# %%
# %time forest = forest.fit(X_train_tf_idf_vector, y_train)
# Out:
# CPU times: user 5min 9s, sys: 883 ms, total: 5min 10s
# Wall time: 1min 27s

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
k_fold = KFold(n_splits = 5, shuffle = True, random_state = 2018)

score = np.mean(cross_val_score(\
                               forest, X_train_tf_idf_vector, \
                               y_train, cv = k_fold, scoring = 'roc_auc', n_jobs = -1))

# %%
format(score)
# Out:
# '0.9109146273252845'

# %%
result = forest.predict(X_test_tf_idf_vector)

# %%
y_test
# Out:
# 5215     1
# 9067     0
# 18853    1
# 8899     1
# 13640    1
#         ..
# 5119     0
# 17938    1
# 15344    1
# 8916     0
# 13295    1
# Name: Rating, Length: 6251, dtype: object

# %%
a = sum(y_test == result)
print("테스트 셋 정확도 :",a / len(y_test))
# Out:
# 테스트 셋 정확도 : 0.8673812190049592

# %% [markdown]
# ### 전체 데이터셋 활용

# %%
df = pd.read_csv('./Amazon_Unlocked_Mobile.csv')

# %%
df = df.dropna(subset= ['Reviews'])

# %%
df.isnull().sum()
# Out:
# Product Name        0
# Brand Name      65155
# Price            5930
# Rating              0
# Reviews             0
# Review Votes    12296
# dtype: int64

# %%
Review_mapping =  {0: '0',1 : '0', 2 :'0',3 : '0', 4 : '1', 5 : '1'}
Review_mapping
# Out:
# {0: '0', 1: '0', 2: '0', 3: '0', 4: '1', 5: '1'}

# %%
Rating = lambda x: Review_mapping.get(x,x)
df['Rating']=df.Rating.map(Rating)

# %%
df
# Out:
#                                              Product Name Brand Name   Price  \
# 0       "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 1       "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 2       "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 3       "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 4       "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# ...                                                   ...        ...     ...
# 413835  Samsung Convoy U640 Phone for Verizon Wireless...    Samsung   79.95
# 413836  Samsung Convoy U640 Phone for Verizon Wireless...    Samsung   79.95
# 413837  Samsung Convoy U640 Phone for Verizon Wireless...    Samsung   79.95
# 413838  Samsung Convoy U640 Phone for Verizon Wireless...    Samsung   79.95
# 413839  Samsung Convoy U640 Phone for Verizon Wireless...    Samsung   79.95
#
#        Rating                                            Reviews  Review Votes
# 0           1  I feel so LUCKY to have found this used (phone...           1.0
# 1           1  nice phone, nice up grade from my pantach revu...           0.0
# 2           1                                       Very pleased           0.0
# 3           1  It works good but it goes slow sometimes but i...           0.0
# 4           1  Great phone to replace my lost phone. The only...           0.0
# ...       ...                                                ...           ...
# 413835      1                     another great deal great price           0.0
# 413836      0                                                 Ok           0.0
# 413837      1        Passes every drop test onto porcelain tile!           0.0
# 413838      0  I returned it because it did not meet my needs...           0.0
# 413839      1  Only downside is that apparently Verizon no lo...           0.0
#
# [413778 rows x 6 columns]

# %%
a = df.iloc[:,3]
b = df.iloc[:,4]

# %%
doc = pd.concat([a,b], axis = 1)
train_docs, test_docs = train_test_split(doc, test_size = 0.3)

# %%
def review_to_wordlist(review, remove_stopwords = True):

    
    review_text = re.sub('[^a-zA-Z]'," ", review)
    #review_text에 영어만 넣기 
    
    words = review_text.lower().split()
    #소문자로 바꿔주고 그것들을 분리해준다 
    
    if remove_stopwords:
        stops = set(stopwords.words('english'))
        words = [w for w in words if not w in stops]
        #stops에 영어의 불용어를 넣어줌 
        #words는 소문자로 변환되고 띄어져있는 것이며 
        #stops에 있는 불용어를 제외하고 넣어줌 
        
    b = []
    stemmer = english_stemmer
    for word in words:
        b.append(stemmer.stem(word))
        #words에 전처리된것들의 어간들만 추출 
        
    return(b)

# %%
clean_train_reviews = []
for review in train_docs['Reviews']:
    clean_train_reviews.append( " ".join(review_to_wordlist(review)))
    
clean_test_reviews = []
for review in test_docs['Reviews']:
    clean_test_reviews.append( " ".join(review_to_wordlist(review)))

# %%
X_train = clean_train_reviews
X_test = clean_test_reviews

y_train = train_docs['Rating']
y_test = test_docs['Rating']

# %%
len(clean_train_reviews)
# Out:
# 289644

# %%
vectorizer = CountVectorizer(analyzer = 'word', 
                             lowercase = True,
                             tokenizer = None,
                             preprocessor = None,
                             stop_words = 'english',
                             min_df = 2, # 토큰이 나타날 최소 문서 개수로 오타나 자주 나오지 않는 특수한 전문용어 제거에 좋다. 
                             ngram_range=(1, 5),
                             vocabulary = set(words.words()), # nltk의 words를 사용하거나 문서 자체의 사전을 만들거나 선택한다. 
                             max_features = 300000
                            )

# %%
pipeline = Pipeline([
    ('vect', vectorizer),
    ('tfidf', TfidfTransformer(smooth_idf = False))
])

# %%
X_train_tf_idf_vector = pipeline.fit_transform(X_train)
X_test_tf_idf_vector = pipeline.fit_transform(X_test)
# Out:
# /Users/Moon/opt/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py:1278: RuntimeWarning: divide by zero encountered in true_divide
#   idf = np.log(n_samples / df) + 1

# %%
forest = RandomForestClassifier(
    n_estimators = 100, n_jobs = -1, random_state=2018)
forest
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=2018, verbose=0,
#                        warm_start=False)

# %%
# %time forest = forest.fit(X_train_tf_idf_vector, y_train)
# Out:
# CPU times: user 1h 37min 15s, sys: 11.2 s, total: 1h 37min 26s
# Wall time: 26min 28s

# %%
k_fold = KFold(n_splits = 5, shuffle = True, random_state = 2018)

score = np.mean(cross_val_score(\
                               forest, X_train_tf_idf_vector, \
                               y_train, cv = k_fold, scoring = 'roc_auc', n_jobs = -1))
print(format(score))
# Out:
# 0.9716094368926219

# %%
result = forest.predict(X_test_tf_idf_vector)
a = sum(y_test == result)
print("테스트 셋 정확도 :",a / len(y_test))
# Out:
# 테스트 셋 정확도 : 0.9392752992733658
